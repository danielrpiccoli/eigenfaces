# %% [markdown]
# # Exploração — Eigenfaces
#
# Notebook para experimentar com o pipeline antes de consolidar nos scripts em `src/`.

# %%
import sys
sys.path.append('../src')

from carregar_dados import carregar_matriz_rostos
from pca import calcular_pca, projetar, reconstruir
import numpy as np
import matplotlib.pyplot as plt

# %%
A, rotulos, altura, largura = carregar_matriz_rostos()
print(A.shape, altura, largura)

# %%
media = A.mean(axis=1)
plt.imshow(media.reshape(altura, largura), cmap='gray')
plt.title('Rosto médio')
plt.axis('off')
